# %%
# Importing the necessary library
import matplotlib.pyplot as plt

# 1: Create data
temperature = [30, 35, 40, 45, 50]  
sales = [10, 8,34,57,43]  


# 2: Create a scatter plot
plt.scatter(temperature,sales, color='black', label='Data points')  
# 3: Create a scatter plot
plt.plot(temp, sales, color="orange", label='Data points') 

# 4: Customize the plot
plt.xlabel('x values')  
plt.ylabel('y values')  
plt.title('Simple Scatter Plot') 
plt.legend()  

# 5: Display the plot
plt.show()
